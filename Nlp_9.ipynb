# %% [markdown]
# <a href="https://colab.research.google.com/github/NandanaRN/Natural_Language_Processing/blob/main/PROJECT_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLP Project 9: Student Feedback Analysis
# # Problem Statement
# A college collects feedback from students about subjects, teaching methods, classroom activities, and overall learning experience. Since feedback is collected from many students across different departments, manual analysis becomes difficult and time-consuming for the administration. The institution wants to use NLP methods to analyze student feedback, identify common concerns, and improve the quality of education and student satisfaction

# %% [markdown]
# Tasks
#
#
# 1.   Collect student feedback data.
# 2.   Preprocess feedback text.
#
#
# 1.   Perform sentiment analysis.
# 2.   Identify common student concerns.
#
#
# 1.   Prepare improvement suggestions.

# %% [markdown]
# Step 1: Import Libraries

# %%
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import string

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from textblob import TextBlob

from wordcloud import WordCloud

# %% [markdown]
# Step 2: Download NLTK Resources

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Step 3: Create Student Feedback Dataset

# %%
feedback = {
    "Feedback": [
        "The faculty explains concepts very clearly.",
        "The syllabus is too lengthy.",
        "Practical sessions are very helpful.",
        "The classroom projector is not working properly.",
        "Assignments improve understanding.",
        "Too many assignments every week.",
        "Faculty is friendly and supportive.",
        "Need more industry-related projects.",
        "Lab equipment should be upgraded.",
        "Excellent teaching methods.",
        "Class timing should be more flexible.",
        "Notes provided are very useful.",
        "Need more interactive sessions.",
        "The course content is interesting.",
        "Placement training should start earlier."
    ]
}

df = pd.DataFrame(feedback)

df.head()
# Out:
#                                            Feedback
# 0       The faculty explains concepts very clearly.
# 1                      The syllabus is too lengthy.
# 2              Practical sessions are very helpful.
# 3  The classroom projector is not working properly.
# 4                Assignments improve understanding.

# %% [markdown]
# Step 4: Preprocess Text

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess(text):

    text = text.lower()

    text = text.translate(str.maketrans('', '', string.punctuation))

    words = word_tokenize(text)

    words = [word for word in words if word not in stop_words]

    words = [lemmatizer.lemmatize(word) for word in words]

    return " ".join(words)

df["Processed_Feedback"] = df["Feedback"].apply(preprocess)

df.head()
# Out:
#                                            Feedback  \
# 0       The faculty explains concepts very clearly.
# 1                      The syllabus is too lengthy.
# 2              Practical sessions are very helpful.
# 3  The classroom projector is not working properly.
# 4                Assignments improve understanding.
#
#                      Processed_Feedback Sentiment
# 0      faculty explains concept clearly  Positive
# 1                      syllabus lengthy   Neutral
# 2             practical session helpful   Neutral
# 3  classroom projector working properly   Neutral
# 4      assignment improve understanding   Neutral

# %% [markdown]
# Step 5: Sentiment Analysis

# %%
def get_sentiment(text):

    polarity = TextBlob(text).sentiment.polarity

    if polarity > 0:
        return "Positive"

    elif polarity < 0:
        return "Negative"

    else:
        return "Neutral"

df["Sentiment"] = df["Processed_Feedback"].apply(get_sentiment)

df
# Out:
#                                             Feedback  \
# 0        The faculty explains concepts very clearly.
# 1                       The syllabus is too lengthy.
# 2               Practical sessions are very helpful.
# 3   The classroom projector is not working properly.
# 4                 Assignments improve understanding.
# 5                   Too many assignments every week.
# 6                Faculty is friendly and supportive.
# 7               Need more industry-related projects.
# 8                  Lab equipment should be upgraded.
# 9                        Excellent teaching methods.
# 10             Class timing should be more flexible.
# 11                   Notes provided are very useful.
# 12                   Need more interactive sessions.
# 13                The course content is interesting.
# 14          Placement training should start earlier.
#
#                       Processed_Feedback Sentiment
# 0       faculty explains concept clearly  Positive
# 1                       syllabus lengthy   Neutral
# 2              practical session helpful   Neutral
# 3   classroom projector working properly   Neutral
# 4       assignment improve understanding   Neutral
# 5             many assignment every week  Positive
# 6            faculty friendly supportive  Positive
# 7           need industryrelated project   Neutral
# 8                 lab equipment upgraded   Neutral
# 9              excellent teaching method  Positive
# 10                 class timing flexible   Neutral
# 11                  note provided useful  Positive
# 12              need interactive session   Neutral
# 13            course content interesting  Positive
# 14      placement training start earlier   Neutral

# %% [markdown]
# Step 6: Count Sentiments

# %%
sentiment_count = df["Sentiment"].value_counts()

print(sentiment_count)
# Out:
# Sentiment
# Neutral     9
# Positive    6
# Name: count, dtype: int64

# %% [markdown]
# Step 7: Plot Sentiment Distribution

# %%
plt.figure(figsize=(6,4))

sentiment_count.plot(kind='bar')

plt.title("Student Feedback Sentiment Analysis")

plt.xlabel("Sentiment")

plt.ylabel("Number of Feedbacks")

plt.show()

# %% [markdown]
# Step 8: Generate Word Cloud

# %%
text = " ".join(df["Processed_Feedback"])

wordcloud = WordCloud(width=900,
                      height=450,
                      background_color="white").generate(text)

plt.figure(figsize=(10,5))

plt.imshow(wordcloud)

plt.axis("off")

plt.show()

# %% [markdown]
# Step 9: Product Improvement Areas

# %%
negative_feedback = df[df["Sentiment"] == "Negative"]

print(negative_feedback[["Feedback"]])
# Out:
# Empty DataFrame
# Columns: [Feedback]
# Index: []

# %% [markdown]
# Step 10: Improvement Suggestions

# %%
suggestions = [
    "Reduce syllabus overload where possible.",
    "Balance assignment workload.",
    "Upgrade classroom equipment.",
    "Improve laboratory facilities.",
    "Introduce more industry-based projects.",
    "Conduct interactive learning sessions.",
    "Start placement preparation earlier."
]

for i, suggestion in enumerate(suggestions, start=1):
    print(f"{i}. {suggestion}")
# Out:
# 1. Reduce syllabus overload where possible.
# 2. Balance assignment workload.
# 3. Upgrade classroom equipment.
# 4. Improve laboratory facilities.
# 5. Introduce more industry-based projects.
# 6. Conduct interactive learning sessions.
# 7. Start placement preparation earlier.

# %% [markdown]
# Step 11: Summary Statistics

# %%
positive = len(df[df["Sentiment"]=="Positive"])
negative = len(df[df["Sentiment"]=="Negative"])
neutral = len(df[df["Sentiment"]=="Neutral"])

print("Positive Feedback :", positive)
print("Negative Feedback :", negative)
print("Neutral Feedback  :", neutral)
# Out:
# Positive Feedback : 6
# Negative Feedback : 0
# Neutral Feedback  : 9
